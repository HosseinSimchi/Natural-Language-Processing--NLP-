# %%
from nltk.tokenize import sent_tokenize 
t = "hello my name is hossein simchi"
print(sent_tokenize(t))
# Out:
# ['hello my name is hossein simchi']

# %%
from nltk.tokenize import word_tokenize 
f = "سلام اسم من حسین است "
print(word_tokenize(f))
# Out:
# ['سلام', 'اسم', 'من', 'حسین', 'است']

# %%
import nltk 
file = open ("C:\\Users\\Lenovo\\Desktop\\matn.txt",encoding = "UTF-8")
y = file.read()
print(y)
# Out:
# ستایش خداوندی را که در یگانگی، والا و در بی¬همتایی، نزدیک و در اقتدار شکوهمند، و در ارکان خود بسی
# بزرگ است. دانشش بر همه چیز احاطه دارد و حال آنکه او در مقام خوش است و آفریدگان، همگی
# مقهور قدرت اویند. بزرگی که پیوسته بوده و ستوده¬ای که همیشه خواهد بود. خوب است آدمی جوری
# زندگی کند که آمدنش چیزی به این دنیا اضافه کند و رفتنش چیزی از آن کم…حضور آدمی باید وزنی در
# این دنیا داشته باشد باید که جای پایش در این دنیا بماند، آدم خوب است که آدم بماند و آدم تر از دنیا
# برود …نیامده ایم تا جمع کنیم آمده ایم تا عشق را ؛ ایمان را ؛ دوستی را ؛ با دیگران قسمت کنیم و غنی
# برویم …آمده ایم تا جای خالی را پر کنیم که فقط و فقط با وجود ما پر میشود و بس !آمده ایم تا بازیگر
# خوب صحنه ی زندگی خود باشیم …پس بهترین بازی خود را به نمایش بگذاریم هر چقدر هم که
# گذشته‌تان آلوده بوده باشد،آینده‌تان هنوز حتی یک لکه هم ندارد.زندگی هر روزتان را با تکه شکسته های
# دیروزتان شروع نکنید.!!!به عقب نگاه نکنید مگر اینکه چشم‌اندازی زیبا باشد.هر روز یک شروع تازه
# است.هر صبح که از خواب بیدار می‌شویم،اولین روز از باقی عمرمان است.یکی از بهترین راه‌ها برای گذشتن
# ازمشکلات گذشته این است….که همه توجه و تمرکزتان را روی کاری جمع کنید که از خودتان در آینده
# برایش متشکر خواهید بود!!!باید راهی یافت، برایِ زندگی را زندگی کردن نه فقط زندگی را گُذَراندَن ..باید
# راهی یافت،برایِ صبح ها با اُمید چشم گُشودَن،برایِ شب ها با آرامشِ خیال خوابیدن..اینطور که
# نمیشود، نمیشود که زندگی را فقط گذراند ، نمیشود که تمام شدنِ فصلی و رسیدنِ فصلی جدید را فقط
# خُنَکایِ ناگهانیِ هوا یادَت بیاورد، نمیشود تا نوکِ دماغَت یخ نکرده حواسَت به رسیدنِ پاییز نباشد..اینطور
# پیش بِرَوی یک آن چَشم باز میکنی خودَت را میانِ خزانِ زردِ زندگی ات میابی ،و یادت هم نمی آید چطور
# گذَرانده ای مسیرِ بهاری و سبزِ زندگی ات را..اصلا خدا را هم خوش نمی آید ، راهَت داده به دنیایَش که
# نقشَت را ایفا کنی، یک روز خوبُ حتی یک روز بد ، یک روز شیرینُ حتی یک روز تلخ ،یک روز آرامُ حتی
# یک روز پُرهیاهو ، وظیفه ی تو زندگی را با تمام و کمالَش زندگی کردن است ، با تمامِ سِکانس هایِ تلخ و
# شیرینَش..نمیشود که همه اش خسته باشی و سَرِ سکانس هایِ تلخ بهانه بیاوری و گوشه ای به قهر کِز کنی
# و بازی نکنی ..حق داری که خستگی ات را در کنی،اما حق نداری که دیگر مسیر را ادامه ندهی ..اینطور که
# نمیشود، تا دیر نشده باید راهی پیدا کرد،باید زندگی را زندگی کرد ..

# %%
from nltk.tokenize import sent_tokenize 
print(sent_tokenize(y))
# Out:
# ['ستایش خداوندی را که در یگانگی، والا و در بی¬همتایی، نزدیک و در اقتدار شکوهمند، و در ارکان خود بسی \nبزرگ است.', 'دانشش بر همه چیز احاطه دارد و حال آنکه او در مقام خوش است و آفریدگان، همگی \nمقهور قدرت اویند.', 'بزرگی که پیوسته بوده و ستوده¬ای که همیشه خواهد بود.', 'خوب است آدمی جوری \nزندگی کند که آمدنش چیزی به این دنیا اضافه کند و رفتنش چیزی از آن کم…حضور آدمی باید وزنی در \nاین دنیا داشته باشد باید که جای پایش در این دنیا بماند، آدم خوب است که آدم بماند و آدم تر از دنیا \nبرود …نیامده ایم تا جمع کنیم آمده ایم تا عشق را ؛ ایمان را ؛ دوستی را ؛ با دیگران قسمت کنیم و غنی \nبرویم …آمده ایم تا جای خالی را پر کنیم که فقط و فقط با وجود ما پر میشود و بس !آمده ایم تا بازیگر \nخوب صحنه ی زندگی خود باشیم …پس بهترین بازی خود را به نمایش بگذاریم هر چقدر هم که \nگذشته\u200cتان آلوده بوده باشد،آینده\u200cتان هنوز حتی یک لکه هم ندارد.زندگی هر روزتان را با تکه شکسته های \nدیروزتان شروع نکنید.!!', '!به عقب نگاه نکنید مگر اینکه چشم\u200cاندازی زیبا باشد.هر روز یک شروع تازه \nاست.هر صبح که از خواب بیدار می\u200cشویم،اولین روز از باقی عمرمان است.یکی از بهترین راه\u200cها برای گذشتن \nازمشکلات گذشته این است….که همه توجه و تمرکزتان را روی کاری جمع کنید که از خودتان در آینده \nبرایش متشکر خواهید بود!!', '!باید راهی یافت، برایِ زندگی را زندگی کردن نه فقط زندگی را گُذَراندَن ..باید \nراهی یافت،برایِ صبح ها با اُمید چشم گُشودَن،برایِ شب ها با آرامشِ خیال خوابیدن..اینطور که \nنمیشود، نمیشود که زندگی را فقط گذراند ، نمیشود که تمام شدنِ فصلی و رسیدنِ فصلی جدید را فقط \nخُنَکایِ ناگهانیِ هوا یادَت بیاورد، نمیشود تا نوکِ دماغَت یخ نکرده حواسَت به رسیدنِ پاییز نباشد..اینطور \nپیش بِرَوی یک آن چَشم باز میکنی خودَت را میانِ خزانِ زردِ زندگی ات میابی ،و یادت هم نمی آید چطور \nگذَرانده ای مسیرِ بهاری و سبزِ زندگی ات را..اصلا خدا را هم خوش نمی آید ، راهَت داده به دنیایَش که \nنقشَت را ایفا کنی، یک روز خوبُ حتی یک روز بد ، یک روز شیرینُ حتی یک روز تلخ ،یک روز آرامُ حتی \nیک روز پُرهیاهو ، وظیفه ی تو زندگی را با تمام و کمالَش زندگی کردن است ، با تمامِ سِکانس هایِ تلخ و \nشیرینَش..نمیشود که همه اش خسته باشی و سَرِ سکانس هایِ تلخ بهانه بیاوری و گوشه ای به قهر کِز کنی \nو بازی نکنی ..حق داری که خستگی ات را در کنی،اما حق نداری که دیگر مسیر را ادامه ندهی ..اینطور که \nنمیشود، تا دیر نشده باید راهی پیدا کرد،باید زندگی را زندگی کرد ..']

# %%
from nltk.tokenize import word_tokenize 
word_tokenize(y)
# Out:
# ['ستایش',
#  'خداوندی',
#  'را',
#  'که',
#  'در',
#  'یگانگی،',
#  'والا',
#  'و',
#  'در',
#  'بی¬همتایی،',
#  'نزدیک',
#  'و',
#  'در',
#  'اقتدار',
#  'شکوهمند،',
#  'و',
#  'در',
#  'ارکان',
#  'خود',
#  'بسی',
#  'بزرگ',
#  'است',
#  '.',
#  'دانشش',
#  'بر',
#  'همه',
#  'چیز',
#  'احاطه',
#  'دارد',
#  'و',
#  'حال',
#  'آنکه',
#  'او',
#  'در',
#  'مقام',
#  'خوش',
#  'است',
#  'و',
#  'آفریدگان،',
#  'همگی',
#  'مقهور',
#  'قدرت',
#  'اویند',
#  '.',
#  'بزرگی',
#  'که',
#  'پیوسته',
#  'بوده',
#  'و',
#  'ستوده¬ای',
#  'که',
#  'همیشه',
#  'خواهد',
#  'بود',
#  '.',
#  'خوب',
#  'است',
#  'آدمی',
#  'جوری',
#  'زندگی',
#  'کند',
#  'که',
#  'آمدنش',
#  'چیزی',
#  'به',
#  'این',
#  'دنیا',
#  'اضافه',
#  'کند',
#  'و',
#  'رفتنش',
#  'چیزی',
#  'از',
#  'آن',
#  'کم…حضور',
#  'آدمی',
#  'باید',
#  'وزنی',
#  'در',
#  'این',
#  'دنیا',
#  'داشته',
#  'باشد',
#  'باید',
#  'که',
#  'جای',
#  'پایش',
#  'در',
#  'این',
#  'دنیا',
#  'بماند،',
#  'آدم',
#  'خوب',
#  'است',
#  'که',
#  'آدم',
#  'بماند',
#  'و',
#  'آدم',
#  'تر',
#  'از',
#  'دنیا',
#  'برود',
#  '…نیامده',
#  'ایم',
#  'تا',
#  'جمع',
#  'کنیم',
#  'آمده',
#  'ایم',
#  'تا',
#  'عشق',
#  'را',
#  '؛',
#  'ایمان',
#  'را',
#  '؛',
#  'دوستی',
#  'را',
#  '؛',
#  'با',
#  'دیگران',
#  'قسمت',
#  'کنیم',
#  'و',
#  'غنی',
#  'برویم',
#  '…آمده',
#  'ایم',
#  'تا',
#  'جای',
#  'خالی',
#  'را',
#  'پر',
#  'کنیم',
#  'که',
#  'فقط',
#  'و',
#  'فقط',
#  'با',
#  'وجود',
#  'ما',
#  'پر',
#  'میشود',
#  'و',
#  'بس',
#  '!',
#  'آمده',
#  'ایم',
#  'تا',
#  'بازیگر',
#  'خوب',
#  'صحنه',
#  'ی',
#  'زندگی',
#  'خود',
#  'باشیم',
#  '…پس',
#  'بهترین',
#  'بازی',
#  'خود',
#  'را',
#  'به',
#  'نمایش',
#  'بگذاریم',
#  'هر',
#  'چقدر',
#  'هم',
#  'که',
#  'گذشته\u200cتان',
#  'آلوده',
#  'بوده',
#  'باشد،آینده\u200cتان',
#  'هنوز',
#  'حتی',
#  'یک',
#  'لکه',
#  'هم',
#  'ندارد.زندگی',
#  'هر',
#  'روزتان',
#  'را',
#  'با',
#  'تکه',
#  'شکسته',
#  'های',
#  'دیروزتان',
#  'شروع',
#  'نکنید.',
#  '!',
#  '!',
#  '!',
#  'به',
#  'عقب',
#  'نگاه',
#  'نکنید',
#  'مگر',
#  'اینکه',
#  'چشم\u200cاندازی',
#  'زیبا',
#  'باشد.هر',
#  'روز',
#  'یک',
#  'شروع',
#  'تازه',
#  'است.هر',
#  'صبح',
#  'که',
#  'از',
#  'خواب',
#  'بیدار',
#  'می\u200cشویم،اولین',
#  'روز',
#  'از',
#  'باقی',
#  'عمرمان',
#  'است.یکی',
#  'از',
#  'بهترین',
#  'راه\u200cها',
#  'برای',
#  'گذشتن',
#  'ازمشکلات',
#  'گذشته',
#  'این',
#  'است….که',
#  'همه',
#  'توجه',
#  'و',
#  'تمرکزتان',
#  'را',
#  'روی',
#  'کاری',
#  'جمع',
#  'کنید',
#  'که',
#  'از',
#  'خودتان',
#  'در',
#  'آینده',
#  'برایش',
#  'متشکر',
#  'خواهید',
#  'بود',
#  '!',
#  '!',
#  '!',
#  'باید',
#  'راهی',
#  'یافت،',
#  'برایِ',
#  'زندگی',
#  'را',
#  'زندگی',
#  'کردن',
#  'نه',
#  'فقط',
#  'زندگی',
#  'را',
#  'گُذَراندَن',
#  '..باید',
#  'راهی',
#  'یافت،برایِ',
#  'صبح',
#  'ها',
#  'با',
#  'اُمید',
#  'چشم',
#  'گُشودَن،برایِ',
#  'شب',
#  'ها',
#  'با',
#  'آرامشِ',
#  'خیال',
#  'خوابیدن..اینطور',
#  'که',
#  'نمیشود،',
#  'نمیشود',
#  'که',
#  'زندگی',
#  'را',
#  'فقط',
#  'گذراند',
#  '،',
#  'نمیشود',
#  'که',
#  'تمام',
#  'شدنِ',
#  'فصلی',
#  'و',
#  'رسیدنِ',
#  'فصلی',
#  'جدید',
#  'را',
#  'فقط',
#  'خُنَکایِ',
#  'ناگهانیِ',
#  'هوا',
#  'یادَت',
#  'بیاورد،',
#  'نمیشود',
#  'تا',
#  'نوکِ',
#  'دماغَت',
#  'یخ',
#  'نکرده',
#  'حواسَت',
#  'به',
#  'رسیدنِ',
#  'پاییز',
#  'نباشد..اینطور',
#  'پیش',
#  'بِرَوی',
#  'یک',
#  'آن',
#  'چَشم',
#  'باز',
#  'میکنی',
#  'خودَت',
#  'را',
#  'میانِ',
#  'خزانِ',
#  'زردِ',
#  'زندگی',
#  'ات',
#  'میابی',
#  '،و',
#  'یادت',
#  'هم',
#  'نمی',
#  'آید',
#  'چطور',
#  'گذَرانده',
#  'ای',
#  'مسیرِ',
#  'بهاری',
#  'و',
#  'سبزِ',
#  'زندگی',
#  'ات',
#  'را..اصلا',
#  'خدا',
#  'را',
#  'هم',
#  'خوش',
#  'نمی',
#  'آید',
#  '،',
#  'راهَت',
#  'داده',
#  'به',
#  'دنیایَش',
#  'که',
#  'نقشَت',
#  'را',
#  'ایفا',
#  'کنی،',
#  'یک',
#  'روز',
#  'خوبُ',
#  'حتی',
#  'یک',
#  'روز',
#  'بد',
#  '،',
#  'یک',
#  'روز',
#  'شیرینُ',
#  'حتی',
#  'یک',
#  'روز',
#  'تلخ',
#  '،یک',
#  'روز',
#  'آرامُ',
#  'حتی',
#  'یک',
#  'روز',
#  'پُرهیاهو',
#  '،',
#  'وظیفه',
#  'ی',
#  'تو',
#  'زندگی',
#  'را',
#  'با',
#  'تمام',
#  'و',
#  'کمالَش',
#  'زندگی',
#  'کردن',
#  'است',
#  '،',
#  'با',
#  'تمامِ',
#  'سِکانس',
#  'هایِ',
#  'تلخ',
#  'و',
#  'شیرینَش..نمیشود',
#  'که',
#  'همه',
#  'اش',
#  'خسته',
#  'باشی',
#  'و',
#  'سَرِ',
#  'سکانس',
#  'هایِ',
#  'تلخ',
#  'بهانه',
#  'بیاوری',
#  'و',
#  'گوشه',
#  'ای',
#  'به',
#  'قهر',
#  'کِز',
#  'کنی',
#  'و',
#  'بازی',
#  'نکنی',
#  '..حق',
#  'داری',
#  'که',
#  'خستگی',
#  'ات',
#  'را',
#  'در',
#  'کنی،اما',
#  'حق',
#  'نداری',
#  'که',
#  'دیگر',
#  'مسیر',
#  'را',
#  'ادامه',
#  'ندهی',
#  '..اینطور',
#  'که',
#  'نمیشود،',
#  'تا',
#  'دیر',
#  'نشده',
#  'باید',
#  'راهی',
#  'پیدا',
#  'کرد،باید',
#  'زندگی',
#  'را',
#  'زندگی',
#  'کرد',
#  '..']

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

pstemer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()
words = word_tokenize(y)

for word in words: 
 print(word + ":" + pstemer.stem(word))

for word in words:
 print(word + ":" + wordnet_lemmatizer.lemmatize(word))
# Out:
# ستایش:ستایش
# خداوندی:خداوندی
# را:را
# که:که
# در:در
# یگانگی،:یگانگی،
# والا:والا
# و:و
# در:در
# بی¬همتایی،:بی¬همتایی،
# نزدیک:نزدیک
# و:و
# در:در
# اقتدار:اقتدار
# شکوهمند،:شکوهمند،
# و:و
# در:در
# ارکان:ارکان
# خود:خود
# بسی:بسی
# بزرگ:بزرگ
# است:است
# .:.
# دانشش:دانشش
# بر:بر
# همه:همه
# چیز:چیز
# احاطه:احاطه
# دارد:دارد
# و:و
# حال:حال
# آنکه:آنکه
# او:او
# در:در
# مقام:مقام
# خوش:خوش
# است:است
# و:و
# آفریدگان،:آفریدگان،
# همگی:همگی
# مقهور:مقهور
# قدرت:قدرت
# اویند:اویند
# .:.
# بزرگی:بزرگی
# که:که
# پیوسته:پیوسته
# بوده:بوده
# و:و
# ستوده¬ای:ستوده¬ای
# که:که
# همیشه:همیشه
# خواهد:خواهد
# بود:بود
# .:.
# خوب:خوب
# است:است
# آدمی:آدمی
# جوری:جوری
# زندگی:زندگی
# کند:کند
# که:که
# آمدنش:آمدنش
# چیزی:چیزی
# به:به
# این:این
# دنیا:دنیا
# اضافه:اضافه
# کند:کند
# و:و
# رفتنش:رفتنش
# چیزی:چیزی
# از:از
# آن:آن
# کم…حضور:کم…حضور
# آدمی:آدمی
# باید:باید
# وزنی:وزنی
# در:در
# این:این
# دنیا:دنیا
# داشته:داشته
# باشد:باشد
# باید:باید
# که:که
# جای:جای
# پایش:پایش
# در:در
# این:این
# دنیا:دنیا
# بماند،:بماند،
# آدم:آدم
# خوب:خوب
# است:است
# که:که
# آدم:آدم
# بماند:بماند
# و:و
# آدم:آدم
# تر:تر
# از:از
# دنیا:دنیا
# برود:برود
# …نیامده:…نیامده
# ایم:ایم
# تا:تا
# جمع:جمع
# کنیم:کنیم
# آمده:آمده
# ایم:ایم
# تا:تا
# عشق:عشق
# را:را
# ؛:؛
# ایمان:ایمان
# را:را
# ؛:؛
# دوستی:دوستی
# را:را
# ؛:؛
# با:با
# دیگران:دیگران
# قسمت:قسمت
# کنیم:کنیم
# و:و
# غنی:غنی
# برویم:برویم
# …آمده:…آمده
# ایم:ایم
# تا:تا
# جای:جای
# خالی:خالی
# را:را
# پر:پر
# کنیم:کنیم
# که:که
# فقط:فقط
# و:و
# فقط:فقط
# با:با
# وجود:وجود
# ما:ما
# پر:پر
# میشود:میشود
# و:و
# بس:بس
# !:!
# آمده:آمده
# ایم:ایم
# تا:تا
# بازیگر:بازیگر
# خوب:خوب
# صحنه:صحنه
# ی:ی
# زندگی:زندگی
# خود:خود
# باشیم:باشیم
# …پس:…پس
# بهترین:بهترین
# بازی:بازی
# خود:خود
# را:را
# به:به
# نمایش:نمایش
# بگذاریم:بگذاریم
# هر:هر
# چقدر:چقدر
# هم:هم
# که:که
# گذشته‌تان:گذشته‌تان
# آلوده:آلوده
# بوده:بوده
# باشد،آینده‌تان:باشد،آینده‌تان
# هنوز:هنوز
# حتی:حتی
# یک:یک
# لکه:لکه
# هم:هم
# ندارد.زندگی:ندارد.زندگی
# هر:هر
# روزتان:روزتان
# را:را
# با:با
# تکه:تکه
# شکسته:شکسته
# های:های
# دیروزتان:دیروزتان
# شروع:شروع
# نکنید.:نکنید.
# !:!
# !:!
# !:!
# به:به
# عقب:عقب
# نگاه:نگاه
# نکنید:نکنید
# مگر:مگر
# اینکه:اینکه
# چشم‌اندازی:چشم‌اندازی
# زیبا:زیبا
# باشد.هر:باشد.هر
# روز:روز
# یک:یک
# شروع:شروع
# تازه:تازه
# است.هر:است.هر
# صبح:صبح
# که:که
# از:از
# خواب:خواب
# بیدار:بیدار
# می‌شویم،اولین:می‌شویم،اولین
# روز:روز
# از:از
# باقی:باقی
# عمرمان:عمرمان
# است.یکی:است.یکی
# از:از
# بهترین:بهترین
# راه‌ها:راه‌ها
# برای:برای
# گذشتن:گذشتن
# ازمشکلات:ازمشکلات
# گذشته:گذشته
# این:این
# است….که:است….که
# همه:همه
# توجه:توجه
# و:و
# تمرکزتان:تمرکزتان
# را:را
# روی:روی
# کاری:کاری
# جمع:جمع
# کنید:کنید
# که:که
# از:از
# خودتان:خودتان
# در:در
# آینده:آینده
# برایش:برایش
# متشکر:متشکر
# خواهید:خواهید
# بود:بود
# !:!
# !:!
# !:!
# باید:باید
# راهی:راهی
# یافت،:یافت،
# برایِ:برایِ
# زندگی:زندگی
# را:را
# زندگی:زندگی
# کردن:کردن
# نه:نه
# فقط:فقط
# زندگی:زندگی
# را:را
# گُذَراندَن:گُذَراندَن
# ..باید:..باید
# راهی:راهی
# یافت،برایِ:یافت،برایِ
# صبح:صبح
# ها:ها
# با:با
# اُمید:اُمید
# چشم:چشم
# گُشودَن،برایِ:گُشودَن،برایِ
# شب:شب
# ها:ها
# با:با
# آرامشِ:آرامشِ
# خیال:خیال
# خوابیدن..اینطور:خوابیدن..اینطور
# که:که
# نمیشود،:نمیشود،
# نمیشود:نمیشود
# که:که
# زندگی:زندگی
# را:را
# فقط:فقط
# گذراند:گذراند
# ،:،
# نمیشود:نمیشود
# که:که
# تمام:تمام
# شدنِ:شدنِ
# فصلی:فصلی
# و:و
# رسیدنِ:رسیدنِ
# فصلی:فصلی
# جدید:جدید
# را:را
# فقط:فقط
# خُنَکایِ:خُنَکایِ
# ناگهانیِ:ناگهانیِ
# هوا:هوا
# یادَت:یادَت
# بیاورد،:بیاورد،
# نمیشود:نمیشود
# تا:تا
# نوکِ:نوکِ
# دماغَت:دماغَت
# یخ:یخ
# نکرده:نکرده
# حواسَت:حواسَت
# به:به
# رسیدنِ:رسیدنِ
# پاییز:پاییز
# نباشد..اینطور:نباشد..اینطور
# پیش:پیش
# بِرَوی:بِرَوی
# یک:یک
# آن:آن
# چَشم:چَشم
# باز:باز
# میکنی:میکنی
# خودَت:خودَت
# را:را
# میانِ:میانِ
# خزانِ:خزانِ
# زردِ:زردِ
# زندگی:زندگی
# ات:ات
# میابی:میابی
# ،و:،و
# یادت:یادت
# هم:هم
# نمی:نمی
# آید:آید
# چطور:چطور
# گذَرانده:گذَرانده
# ای:ای
# مسیرِ:مسیرِ
# بهاری:بهاری
# و:و
# سبزِ:سبزِ
# زندگی:زندگی
# ات:ات
# را..اصلا:را..اصلا
# خدا:خدا
# را:را
# هم:هم
# خوش:خوش
# نمی:نمی
# آید:آید
# ،:،
# راهَت:راهَت
# داده:داده
# به:به
# دنیایَش:دنیایَش
# که:که
# نقشَت:نقشَت
# را:را
# ایفا:ایفا
# کنی،:کنی،
# یک:یک
# روز:روز
# خوبُ:خوبُ
# حتی:حتی
# یک:یک
# روز:روز
# بد:بد
# ،:،
# یک:یک
# روز:روز
# شیرینُ:شیرینُ
# حتی:حتی
# یک:یک
# روز:روز
# تلخ:تلخ
# ،یک:،یک
# روز:روز
# آرامُ:آرامُ
# حتی:حتی
# یک:یک
# روز:روز
# پُرهیاهو:پُرهیاهو
# ،:،
# وظیفه:وظیفه
# ی:ی
# تو:تو
# زندگی:زندگی
# را:را
# با:با
# تمام:تمام
# و:و
# کمالَش:کمالَش
# زندگی:زندگی
# کردن:کردن
# است:است
# ،:،
# با:با
# تمامِ:تمامِ
# سِکانس:سِکانس
# هایِ:هایِ
# تلخ:تلخ
# و:و
# شیرینَش..نمیشود:شیرینَش..نمیشود
# که:که
# همه:همه
# اش:اش
# خسته:خسته
# باشی:باشی
# و:و
# سَرِ:سَرِ
# سکانس:سکانس
# هایِ:هایِ
# تلخ:تلخ
# بهانه:بهانه
# بیاوری:بیاوری
# و:و
# گوشه:گوشه
# ای:ای
# به:به
# قهر:قهر
# کِز:کِز
# کنی:کنی
# و:و
# بازی:بازی
# نکنی:نکنی
# ..حق:..حق
# داری:داری
# که:که
# خستگی:خستگی
# ات:ات
# را:را
# در:در
# کنی،اما:کنی،اما
# حق:حق
# نداری:نداری
# که:که
# دیگر:دیگر
# مسیر:مسیر
# را:را
# ادامه:ادامه
# ندهی:ندهی
# ..اینطور:..اینطور
# که:که
# نمیشود،:نمیشود،
# تا:تا
# دیر:دیر
# نشده:نشده
# باید:باید
# راهی:راهی
# پیدا:پیدا
# کرد،باید:کرد،باید
# زندگی:زندگی
# را:را
# زندگی:زندگی
# کرد:کرد
# ..:..
# ستایش:ستایش
# خداوندی:خداوندی
# را:را
# که:که
# در:در
# یگانگی،:یگانگی،
# والا:والا
# و:و
# در:در
# بی¬همتایی،:بی¬همتایی،
# نزدیک:نزدیک
# و:و
# در:در
# اقتدار:اقتدار
# شکوهمند،:شکوهمند،
# و:و
# در:در
# ارکان:ارکان
# خود:خود
# بسی:بسی
# بزرگ:بزرگ
# است:است
# .:.
# دانشش:دانشش
# بر:بر
# همه:همه
# چیز:چیز
# احاطه:احاطه
# دارد:دارد
# و:و
# حال:حال
# آنکه:آنکه
# او:او
# در:در
# مقام:مقام
# خوش:خوش
# است:است
# و:و
# آفریدگان،:آفریدگان،
# همگی:همگی
# مقهور:مقهور
# قدرت:قدرت
# اویند:اویند
# .:.
# بزرگی:بزرگی
# که:که
# پیوسته:پیوسته
# بوده:بوده
# و:و
# ستوده¬ای:ستوده¬ای
# که:که
# همیشه:همیشه
# خواهد:خواهد
# بود:بود
# .:.
# خوب:خوب
# است:است
# آدمی:آدمی
# جوری:جوری
# زندگی:زندگی
# کند:کند
# که:که
# آمدنش:آمدنش
# چیزی:چیزی
# به:به
# این:این
# دنیا:دنیا
# اضافه:اضافه
# کند:کند
# و:و
# رفتنش:رفتنش
# چیزی:چیزی
# از:از
# آن:آن
# کم…حضور:کم…حضور
# آدمی:آدمی
# باید:باید
# وزنی:وزنی
# در:در
# این:این
# دنیا:دنیا
# داشته:داشته
# باشد:باشد
# باید:باید
# که:که
# جای:جای
# پایش:پایش
# در:در
# این:این
# دنیا:دنیا
# بماند،:بماند،
# آدم:آدم
# خوب:خوب
# است:است
# که:که
# آدم:آدم
# بماند:بماند
# و:و
# آدم:آدم
# تر:تر
# از:از
# دنیا:دنیا
# برود:برود
# …نیامده:…نیامده
# ایم:ایم
# تا:تا
# جمع:جمع
# کنیم:کنیم
# آمده:آمده
# ایم:ایم
# تا:تا
# عشق:عشق
# را:را
# ؛:؛
# ایمان:ایمان
# را:را
# ؛:؛
# دوستی:دوستی
# را:را
# ؛:؛
# با:با
# دیگران:دیگران
# قسمت:قسمت
# کنیم:کنیم
# و:و
# غنی:غنی
# برویم:برویم
# …آمده:…آمده
# ایم:ایم
# تا:تا
# جای:جای
# خالی:خالی
# را:را
# پر:پر
# کنیم:کنیم
# که:که
# فقط:فقط
# و:و
# فقط:فقط
# با:با
# وجود:وجود
# ما:ما
# پر:پر
# میشود:میشود
# و:و
# بس:بس
# !:!
# آمده:آمده
# ایم:ایم
# تا:تا
# بازیگر:بازیگر
# خوب:خوب
# صحنه:صحنه
# ی:ی
# زندگی:زندگی
# خود:خود
# باشیم:باشیم
# …پس:…پس
# بهترین:بهترین
# بازی:بازی
# خود:خود
# را:را
# به:به
# نمایش:نمایش
# بگذاریم:بگذاریم
# هر:هر
# چقدر:چقدر
# هم:هم
# که:که
# گذشته‌تان:گذشته‌تان
# آلوده:آلوده
# بوده:بوده
# باشد،آینده‌تان:باشد،آینده‌تان
# هنوز:هنوز
# حتی:حتی
# یک:یک
# لکه:لکه
# هم:هم
# ندارد.زندگی:ندارد.زندگی
# هر:هر
# روزتان:روزتان
# را:را
# با:با
# تکه:تکه
# شکسته:شکسته
# های:های
# دیروزتان:دیروزتان
# شروع:شروع
# نکنید.:نکنید.
# !:!
# !:!
# !:!
# به:به
# عقب:عقب
# نگاه:نگاه
# نکنید:نکنید
# مگر:مگر
# اینکه:اینکه
# چشم‌اندازی:چشم‌اندازی
# زیبا:زیبا
# باشد.هر:باشد.هر
# روز:روز
# یک:یک
# شروع:شروع
# تازه:تازه
# است.هر:است.هر
# صبح:صبح
# که:که
# از:از
# خواب:خواب
# بیدار:بیدار
# می‌شویم،اولین:می‌شویم،اولین
# روز:روز
# از:از
# باقی:باقی
# عمرمان:عمرمان
# است.یکی:است.یکی
# از:از
# بهترین:بهترین
# راه‌ها:راه‌ها
# برای:برای
# گذشتن:گذشتن
# ازمشکلات:ازمشکلات
# گذشته:گذشته
# این:این
# است….که:است….که
# همه:همه
# توجه:توجه
# و:و
# تمرکزتان:تمرکزتان
# را:را
# روی:روی
# کاری:کاری
# جمع:جمع
# کنید:کنید
# که:که
# از:از
# خودتان:خودتان
# در:در
# آینده:آینده
# برایش:برایش
# متشکر:متشکر
# خواهید:خواهید
# بود:بود
# !:!
# !:!
# !:!
# باید:باید
# راهی:راهی
# یافت،:یافت،
# برایِ:برایِ
# زندگی:زندگی
# را:را
# زندگی:زندگی
# کردن:کردن
# نه:نه
# فقط:فقط
# زندگی:زندگی
# را:را
# گُذَراندَن:گُذَراندَن
# ..باید:..باید
# راهی:راهی
# یافت،برایِ:یافت،برایِ
# صبح:صبح
# ها:ها
# با:با
# اُمید:اُمید
# چشم:چشم
# گُشودَن،برایِ:گُشودَن،برایِ
# شب:شب
# ها:ها
# با:با
# آرامشِ:آرامشِ
# خیال:خیال
# خوابیدن..اینطور:خوابیدن..اینطور
# که:که
# نمیشود،:نمیشود،
# نمیشود:نمیشود
# که:که
# زندگی:زندگی
# را:را
# فقط:فقط
# گذراند:گذراند
# ،:،
# نمیشود:نمیشود
# که:که
# تمام:تمام
# شدنِ:شدنِ
# فصلی:فصلی
# و:و
# رسیدنِ:رسیدنِ
# فصلی:فصلی
# جدید:جدید
# را:را
# فقط:فقط
# خُنَکایِ:خُنَکایِ
# ناگهانیِ:ناگهانیِ
# هوا:هوا
# یادَت:یادَت
# بیاورد،:بیاورد،
# نمیشود:نمیشود
# تا:تا
# نوکِ:نوکِ
# دماغَت:دماغَت
# یخ:یخ
# نکرده:نکرده
# حواسَت:حواسَت
# به:به
# رسیدنِ:رسیدنِ
# پاییز:پاییز
# نباشد..اینطور:نباشد..اینطور
# پیش:پیش
# بِرَوی:بِرَوی
# یک:یک
# آن:آن
# چَشم:چَشم
# باز:باز
# میکنی:میکنی
# خودَت:خودَت
# را:را
# میانِ:میانِ
# خزانِ:خزانِ
# زردِ:زردِ
# زندگی:زندگی
# ات:ات
# میابی:میابی
# ،و:،و
# یادت:یادت
# هم:هم
# نمی:نمی
# آید:آید
# چطور:چطور
# گذَرانده:گذَرانده
# ای:ای
# مسیرِ:مسیرِ
# بهاری:بهاری
# و:و
# سبزِ:سبزِ
# زندگی:زندگی
# ات:ات
# را..اصلا:را..اصلا
# خدا:خدا
# را:را
# هم:هم
# خوش:خوش
# نمی:نمی
# آید:آید
# ،:،
# راهَت:راهَت
# داده:داده
# به:به
# دنیایَش:دنیایَش
# که:که
# نقشَت:نقشَت
# را:را
# ایفا:ایفا
# کنی،:کنی،
# یک:یک
# روز:روز
# خوبُ:خوبُ
# حتی:حتی
# یک:یک
# روز:روز
# بد:بد
# ،:،
# یک:یک
# روز:روز
# شیرینُ:شیرینُ
# حتی:حتی
# یک:یک
# روز:روز
# تلخ:تلخ
# ،یک:،یک
# روز:روز
# آرامُ:آرامُ
# حتی:حتی
# یک:یک
# روز:روز
# پُرهیاهو:پُرهیاهو
# ،:،
# وظیفه:وظیفه
# ی:ی
# تو:تو
# زندگی:زندگی
# را:را
# با:با
# تمام:تمام
# و:و
# کمالَش:کمالَش
# زندگی:زندگی
# کردن:کردن
# است:است
# ،:،
# با:با
# تمامِ:تمامِ
# سِکانس:سِکانس
# هایِ:هایِ
# تلخ:تلخ
# و:و
# شیرینَش..نمیشود:شیرینَش..نمیشود
# که:که
# همه:همه
# اش:اش
# خسته:خسته
# باشی:باشی
# و:و
# سَرِ:سَرِ
# سکانس:سکانس
# هایِ:هایِ
# تلخ:تلخ
# بهانه:بهانه
# بیاوری:بیاوری
# و:و
# گوشه:گوشه
# ای:ای
# به:به
# قهر:قهر
# کِز:کِز
# کنی:کنی
# و:و
# بازی:بازی
# نکنی:نکنی
# ..حق:..حق
# داری:داری
# که:که
# خستگی:خستگی
# ات:ات
# را:را
# در:در
# کنی،اما:کنی،اما
# حق:حق
# نداری:نداری
# که:که
# دیگر:دیگر
# مسیر:مسیر
# را:را
# ادامه:ادامه
# ندهی:ندهی
# ..اینطور:..اینطور
# که:که
# نمیشود،:نمیشود،
# تا:تا
# دیر:دیر
# نشده:نشده
# باید:باید
# راهی:راهی
# پیدا:پیدا
# کرد،باید:کرد،باید
# زندگی:زندگی
# را:را
# زندگی:زندگی
# کرد:کرد
# ..:..
